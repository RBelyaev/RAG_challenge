# %%
import pandas as pd
data = pd.read_csv('export.csv')

data.sort_values(axis=0, by='rank').head(50)
# Out:
#      rank               team signature     R     G  Score  Missing  \
# 168     1        kosmynin_v1  af7aeaae  98.5  93.0  142.2        0
# 169     2              teste  47508b36  79.5  80.5  120.2        0
# 170     3         Romanov_v3  54c133f1  80.4  78.0  118.2        0
# 171     4         Sissoko_v2  6097ad4c  78.2  78.5  117.6        0
# 172     5   kostromitskii_v2  42cfe2a3  78.2  77.9  117.0        0
# 173     6         Romanov_v1  278749bb  80.5  76.5  116.8        0
# 174     7         Romanov_v2  674f7857  80.1  76.5  116.6        0
# 175     8         Romanov_v0  f18af354  79.9  76.5  116.5        0
# 176     9       Demidenko_v0  d6f3c9b9  80.7  75.5  115.8        0
# 177    10         Romanov_v7  85f20173  80.6  75.0  115.3        0
# 178    11         Romanov_v6  b88a92db  81.0  74.0  114.5        0
# 179    12   kostromitskii_v1  8d0be499  78.8  75.0  114.4        0
# 180    13         Romanov_v4  4ba8c94b  78.7  74.5  113.9        0
# ...
